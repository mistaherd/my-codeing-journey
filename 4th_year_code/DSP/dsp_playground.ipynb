# %%
! pip install opencv-python
# Out:
# ...
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/fb/c4/f574ba6f04e6d7bf8c38d23e7a52389566dd7631fee0bcdd79ea07ef2dbf/opencv_python-4.8.0.76-cp37-abi3-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#     --------------------------------------- 0.6/38.1 MB 12.0 MB/s eta 0:00:04
#    - -------------------------------------- 1.4/38.1 MB 15.0 MB/s eta 0:00:03
#    -- ------------------------------------- 2.7/38.1 MB 18.7 MB/s eta 0:00:02
#    ---- ----------------------------------- 4.2/38.1 MB 22.2 MB/s eta 0:00:02
#    ------ --------------------------------- 6.0/38.1 MB 25.8 MB/s eta 0:00:02
#    -------- ------------------------------- 7.9/38.1 MB 28.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 9.8/38.1 MB 29.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 10.9/38.1 MB 31.2 MB/s eta 0:00:01
# ...

# %%
import numpy as np
#xn =[2,3,-2,1]
xn=[2,6,2,2,3,4,2,4,6,3,4,5,6,7,8,9]
xn =np.array(xn)
hn=[2,4,5,3,-1,1]
hn =np.array(hn)


yn=np.convolve(xn,hn)
print(yn)
yn=np.convolve(xn,hn,"same")
print(yn)
# Out:
# [  4  20  38  48  40  32  45  45  49  55  64  57  59  78  88 102  96  68
#   26  -1   9]
# [ 38  48  40  32  45  45  49  55  64  57  59  78  88 102  96  68]

# %% [markdown]
# # DFT

# %%
import matplotlib.pylab as plt
pn = xn +3

plt.plot(xn)


zn = np.fft.fft(xn)
plt.stem(np.abs(zn))
zn
# Out:
# array([73.         +0.j        ,  6.21946338+14.96549831j,
#         1.82842712 +9.65685425j, -3.76695967 +2.20851272j,
#         1.         +0.j        , -9.88989458 -3.10519578j,
#        -3.82842712 +1.65685425j, -8.56260914 -2.34821019j,
#        -7.         +0.j        , -8.56260914 +2.34821019j,
#        -3.82842712 -1.65685425j, -9.88989458 +3.10519578j,
#         1.         +0.j        , -3.76695967 -2.20851272j,
#         1.82842712 -9.65685425j,  6.21946338-14.96549831j])

# %%
t= np.linspace(0,10,100)
f1= 40
f2 =200
f3 =83

result=5*np.cos(2*np.pi*f2*t)+5*np.sin(2*np.pi*f1*t)
a= np.abs((np.fft.fft(result))/2)
#plt.plot(t,result)
#plt.plot(np.fft.fftshift(result))
plt.stem(a)
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # NON zero padding method

# %%
maf3p= np.ones(3)/3
a= np.fft.fft(maf3p)
a= np.abs(a)
plt.plot(a)

# %%
zerovar= np.zeros(100)
zerovar[0:3] =maf3p
a= np.fft.fft(zerovar)
a= np.abs(a)
plt.plot(a)
