# %% [markdown]
# open an application

# %%
import subprocess
subprocess.Popen('C:\\Windows\\System32\\calc.exe')

# %% [markdown]
# now lets try to open remedy

# %% [markdown]
# "C:\Users\HoganL\AppData\Roaming\Microsoft\Internet Explorer\Quick Launch\User Pinned\TaskBar\BMC Remedy User.lnk"

# %%
import os
open_remedy=os.startfile(r"C:\\Users\\HoganL\\AppData\\Roaming\\Microsoft\\Internet Explorer\\Quick Launch\\User Pinned\\TaskBar\BMC Remedy User.lnk")

# %%
from pathlib import  Path
import win32com.client
output_dir= Path.cwd() /"Output"
output_dir.mkdir(parents=True ,exist_ok=True)

outlook =win32com.client.Dispatch("Outlook.Application").GetNamespace("MAPI")

inbox= outlook.GetDefaultFolder(6)

output_dir
# Out:
# WindowsPath('c:/Users/HoganL/Documents/GitHub/my-codeing-journey/Output')

# %%
from pathlib import  Path
import win32com.client
import os

output_dir= Path.cwd()/"Output"
output_dir.mkdir(parents=True ,exist_ok=True)



outlook =win32com.client.Dispatch("Outlook.Application").GetNamespace("MAPI")

inbox= outlook.GetDefaultFolder(6)

messages = inbox.Items

for message in messages:
          subject = message.Subject
          body =message.body
          attachments =message.Attachments

          target_folder =output_dir /str(subject)
          target_folder.mkdir(parents=True, exist_ok=True)

          Path(target_folder /"Email_body.txt").write_text(str(body))

for attachment in attachments:
        attachment.SaveasFile(target_folder/ str(attachment))
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-21-f3c68849fe4f> in <module>()
#      20
#      21           target_folder =output_dir /str(subject)
# ---> 22           target_folder.mkdir(parents=True, exist_ok=True)
#      23
#      24           Path(target_folder /"Email_body.txt").write_text(str(body))
#
# c:\ProgramData\Anaconda3\lib\pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1244             self._raise_closed()
#    1245         try:
# -> 1246             self._accessor.mkdir(self, mode)
#    1247         except FileNotFoundError:
#    1248             if not parents or self.parent == self:
#
# c:\ProgramData\Anaconda3\lib\pathlib.py in wrapped(pathobj, *args)
#     385         @functools.wraps(strfunc)
#     386         def wrapped(pathobj, *args):
# --> 387             return strfunc(str(pathobj), *args)
#     388         return staticmethod(wrapped)
#     389
#
# NotADirectoryError: [WinError 267] The directory name is invalid: 'c:\\Users\\HoganL\\Documents\\GitHub\\my-codeing-journey\\Output\\RE: RP651R2 Grafton Merchanting Ashfield, Naas Road, Clondalkin, Dublin 22'

# %%
import docx
import os
import pandas as pd

# %%
from docx import Document
import pandas as pd
def open_lastest_word_doc(word_doc_name):
    doc = docx.Document(word_doc_name)
    tables=[]
    for table in doc.tables:
        df =[['' for i in range(len(table.columns))]for j in range(len(table.rows))]
        for i, row in enumerate(table.rows):
            for j, cell in enumerate(row.cells):
                if cell.text:
                    df[i][j] =cell.text
        tables.append(pd.DataFrame(df))
    tables

# %%
def get_word_doc_name():
    import glob
    list_of_files = glob.glob('C:/Users/HoganL/Downloads/*.docx')
    latest_file =max(list_of_files,key=os.path.getctime)
    return latest_file

# %%
word_doc_name=get_word_doc_name()
word_doc=word_doc_name.replace('\\','/')
word_doc
open_lastest_word_doc(word_doc)
# Out:
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# <ipython-input-7-a32397e80459> in <module>()
#       2 word_doc=word_doc_name.replace('\\','/')
#       3 word_doc
# ----> 4 open_lastest_word_doc(word_doc)
#
# <ipython-input-6-4ad1a2063cd3> in open_lastest_word_doc(word_doc_name)
#       2 import pandas as pd
#       3 def open_lastest_word_doc(word_doc_name):
# ----> 4     doc = docx.Document(word_doc_name)
#       5     tables=[]
#       6     for table in doc.tables:
#
# c:\ProgramData\Anaconda3\lib\site-packages\docx\api.py in Document(docx)
#      23     """
#      24     docx = _default_docx_path() if docx is None else docx
# ---> 25     document_part = Package.open(docx).main_document_part
#      26     if document_part.content_type != CT.WML_DOCUMENT_MAIN:
#      27         tmpl = "file '%s' is not a Word file, content type is '%s'"
#
# c:\ProgramData\Anaconda3\lib\site-packages\docx\opc\package.py in open(cls, pkg_file)
#     126         *pkg_file*.
#     127         """
# --> 128         pkg_reader = PackageReader.from_file(pkg_file)
#     129         package = cls()
#     130         Unmarshaller.unmarshal(pkg_reader, package, PartFactory)
#
# c:\ProgramData\Anaconda3\lib\site-packages\docx\opc\pkgreader.py in from_file(pkg_file)
#      30         Return a |PackageReader| instance loaded with contents of *pkg_file*.
#      31         """
# ---> 32         phys_reader = PhysPkgReader(pkg_file)
#      33         content_types = _ContentTypeMap.from_xml(phys_reader.content_types_xml)
#      34         pkg_srels = PackageReader._srels_for(phys_reader, PACKAGE_URI)
#
# c:\ProgramData\Anaconda3\lib\site-packages\docx\opc\phys_pkg.py in __new__(cls, pkg_file)
#      29             else:
#      30                 raise PackageNotFoundError(
# ---> 31                     "Package not found at '%s'" % pkg_file
#      32                 )
#      33         else:  # assume it's a stream and pass it to Zip reader to sort out
#
# PackageNotFoundError: Package not found at 'C:/Users/HoganL/Downloads/~$dafone Ireland MOP MO088 Callow KTL.docx'

# %% [markdown]
# my intial was idea look like  the following :
# ![flowchart.png](attachment:flowchart.png)
#
# this was and  ok thing but dint do the job now i have  2 months under my belt  the following was the flow chart i came up with the following
# ![newflowdigram.png](attachment:newflowdigram.png)
# lets try and build this

# %%
def promptuser():
    import re
    userprompt = input("how many CRQs do you want ? ")
    
    while(not userprompt.isnumeric()):
        userprompt = input("please enter a input that is a number: ")
    userprompt = int(userprompt)
    return userprompt

# %%
import ctypes
import pandas as pd
import keyboard as kb
import time

CF_TEXT = 1
kernel32 = ctypes.windll.kernel32
kernel32.GlobalLock.argtypes = [ctypes.c_void_p]
kernel32.GlobalLock.restype = ctypes.c_void_p
kernel32.GlobalUnlock.argtypes = [ctypes.c_void_p]
user32 = ctypes.windll.user32
user32.GetClipboardData.restype = ctypes.c_void_p

def get_clipboard_text():
    user32.OpenClipboard(0)
    try:
        if user32.IsClipboardFormatAvailable(CF_TEXT):
            data = user32.GetClipboardData(CF_TEXT)
            data_locked = kernel32.GlobalLock(data)
            text = ctypes.c_char_p(data_locked)
            value = text.value
            kernel32.GlobalUnlock(data_locked)
            new_value=value.decode("utf-8")
            print(new_value)
            return new_value
    finally:
        user32.CloseClipboard()

def promptuser():
    import re
    userprompt = input("how many CRQs do you want ? ")
    
    while(not userprompt.isnumeric()):
        userprompt = input("please enter a input that is a number: ")
    userprompt = int(userprompt)
    return userprompt


def main():
    list=[]
    count= 0
    promptnumb =promptuser()-1
    
    
    while(1):
        list.append(get_clipboard_text())
        count = count+1
        promptnumb = promptnumb-1
        if(input("do you want to continue y/n: ")=='n' or promptnumb== 0):
            if(promptnumb != 0 and input("are you sure want to exit your request for {} copies has not been forfilled y/n: ".format(promptnumb))== 'y'):
                break
        else:
            time.sleep(2)
            print("you have printed {} so far out of {} so far".format(count+1,promptnumb))    
            
    clipboard_Session= pd.Series(list)
    data = pd.DataFrame(clipboard_Session)
    data.head()
    print(clipboard_Session)

    data.to_csv("data.csv")

main()
# Out:
# promptnumb
# you have printed 2 so far out of 18 so far
# promptnumb
# 0    promptnumb
# 1    promptnumb
# dtype: object

# %%
# Out:
# None
# now you have establised when the current week is hold up for the updated

# %%
def week_update(currentweekstr):
    import re
    regex = re.compile(r"(\d{1,2}\D+?)?(\d{1,2}\D+?\d{4})(-\d{1,2}\D+?)?(\d{1,2}\D+?\d{4}) ")
    
    print(regex.match(currentweekstr))
        #currentweekstr=input("please enter in the start of the week to the  end of the week for example 25/03/2023-26/03/2023")
    
    print("now you have establised when the current week is hold up for the updated")

week_update('2.3.2009-5.3.2023')
# Out:
# None
# now you have establised when the current week is hold up for the updated
